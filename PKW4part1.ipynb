# %%
plt.plot(x, stats.norm.pdf(x, loc=-2, scale = 1), label='loc = -2, scale = 1')
plt.plot(x, stats.norm.pdf(x, loc= 2, scale = 5), label='loc = 2, scale = 5')
plt.title("normal distribution")
plt.legend()
plt.show()

# %%
plt.plot(x, stats.gamma.pdf(x, a = 2, scale = 1/5), label='a = 2, scale = 1/5')
plt.plot(x, stats.gamma.pdf(x, a= 3, scale = 1/2), label='a = 3, scale = 1/2')
plt.title("gamma distribution")
plt.legend()
plt.show()

# %%
plt.plot(x, stats.beta.pdf(x, a = 1, b = 1), label='a = 1, b = 1')
plt.plot(x, stats.beta.pdf(x, a = 3, b = 5), label='a = 3, b = 5')
plt.title("normal distribution")
plt.legend()
plt.show()

# %%
x = np.linspace(-7, 7, 500)
rn = stats.norm.rvs(size = 100, loc=0, scale = 3)
plt.hist(rn, bins = 20, weights=np.ones(len(rn)) / len(rn))
plt.plot(x, stats.norm.pdf(x, loc=0, scale = 3), label='loc = -2, scale = 1')

plt.show()

# %%
x = np.linspace(-7, 7, 500)
rn = stats.gamma.rvs(size = 100, a= 3, scale = 1/2)
plt.hist(rn, bins = 20, weights=np.ones(len(rn)) / len(rn))
plt.plot(x, stats.gamma.pdf(x, a= 3, scale = 1/2))

plt.show()

# %%
x = np.linspace(-7, 7, 500)
rn = stats.beta.rvs(size = 100, a = 1, b = 1)

plt.hist(rn, bins = 20, weights=np.ones(len(rn)) / len(rn))
plt.plot(x, stats.beta.pdf(x, a = 1, b = 1))

plt.show()
